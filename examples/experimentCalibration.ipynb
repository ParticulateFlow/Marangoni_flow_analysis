# %%
import sys
sys.path.append("..")

import cv2
from maragoniProcessing.scalingFactor import scalingFactor
import matplotlib.pyplot as plt

calibImg = cv2.imread("../images/calibration_image.jpg")
plt.imshow(calibImg)
plt.show()

# %%
scal, calibImg = scalingFactor(
    calib_img=calibImg,
    patternSize=(4,4),
    checkerSize=10)
print(f"Skalierungsfaktor = {scal:.2f} mm/pix")
plt.imshow(calibImg)
plt.show()
# Out:
# Skalierungsfaktor = 0.03 mm/pix
